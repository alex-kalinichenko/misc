# %%
#!pip install autoviml

# %%
from autoviml.Auto_ViML import Auto_ViML
import pandas as pd
import os

# %%
path = '../../../work/ppd/data/'

# %%
data = pd.read_pickle(os.path.join(path, 'df_break_markup.pkl'))
print(data.shape)
data.head()
# Out:
# (735432, 31)
#   Скважина                Дата  Cos ф (ТМ)  F ТМ  F вращ ТМ  I A ТМ  I C ТМ  \
# 0      565 2017-11-24 16:56:12         NaN   NaN        NaN     NaN     NaN
# 1      565 2017-11-24 16:57:10         NaN   NaN        NaN     NaN     NaN
# 2      565 2017-11-24 16:58:15         NaN   NaN        NaN     NaN     NaN
# 3      565 2017-11-24 16:59:12         NaN   NaN        NaN     NaN     NaN
# 4      565 2017-11-24 17:00:12         NaN   NaN        NaN     NaN     NaN
#
#    I В ТМ  I ТМ  R изол ТМ  U AB (ТМ)  U BC (ТМ)  U CA (ТМ)  W акт (ТМ), Вт  \
# 0     NaN   NaN        NaN        NaN        NaN        NaN             NaN
# 1     NaN   NaN        NaN        NaN        NaN        NaN             NaN
# 2     NaN   NaN        NaN        NaN        NaN        NaN             NaN
# 3     NaN   NaN        NaN        NaN        NaN        NaN             NaN
# 4     NaN   NaN        NaN        NaN        NaN        NaN             NaN
#
#    Дисб. I (ТМ), %  Дисб. U (ТМ), %  Загр. ПЭД (ТМ)  Рэцн ТМ  Тдвиг ТМ  \
# 0              NaN              NaN             NaN      NaN     46.00
# 1              NaN              NaN             NaN      NaN     46.00
# 2              NaN              NaN             NaN      NaN     46.00
# 3              NaN              NaN             NaN      NaN     47.00
# 4              NaN              NaN             NaN      NaN     47.00
#
#    Темп. ж. ТМ  Э/э (Wакт)  Э/э реакт. (ТМ)  Э/э счет. (ТМ)  Рлин ТМ  Qгаз ТМ  \
# 0        33.00         NaN              NaN             NaN      NaN      NaN
# 1        33.00         NaN              NaN             NaN      NaN      NaN
# 2        33.00         NaN              NaN             NaN      NaN      NaN
# 3        33.00         NaN              NaN             NaN      NaN      NaN
# 4        33.00         NaN              NaN             NaN      NaN      NaN
#
#    Qж ТМ  Qж_мас ТМ  Qн ТМ  Обв ТМ  break  risk
# 0    NaN        NaN    NaN     NaN      0  0.00
# 1    NaN        NaN    NaN     NaN      0  0.00
# 2    NaN        NaN    NaN     NaN      0  0.00
# 3    NaN        NaN    NaN     NaN      0  0.00
# 4    NaN        NaN    NaN     NaN      0  0.00

# %%
# устанавливаем дату-время как индекс. При этом повторяющиеся даты будут удалены
data.set_index('Дата', inplace=True, verify_integrity=False)

# %%
# удаляем специальные символы в именах столбцов, иначе в LGBM ошибка
data.columns = data.columns.str.replace('[%,#,@,&]', '', regex=True)

# %% [markdown]
# ```
# #Basic Example with all parameters
# model, features, trainm, testm = Auto_ViML(
#     train,
#     target,
#     test,
#     sample_submission,
#     hyper_param="GS",
#     feature_reduction=True,
#     scoring_parameter="weighted-f1",
#     KMeans_Featurizer=False,
#     Boosting_Flag=False,
#     Binning_Flag=False,
#     Add_Poly=False,
#     Stacking_Flag=False,
#     Imbalanced_Flag=False,
#     verbose=0,
# )
# ```
#
# - `train`: должен содержать местоположение вашего датасета или, если вы загрузили его в dataframe, то имя dataframe. В нашем случае мы загрузили его в dataframe с именем «df», поэтому мы дадим ему значение «df».
# - `target`: содержит имя целевой переменной. В нашем случае она называется «TenYearCHD».
# - `test`: содержит тестовый датасет. Также мы можем оставить его пустым (и использовать ””), если у вас нет никакого тестового датасета, чтобы AutoVIML разделил датасет на обучающий и тестовый.
# - `sample_submission`: мы оставим его пустым, чтобы он автоматически создавал представление в локальном каталоге.
# - `hyper_param`: Мы будем использовать RandomizedSearchCV, потому что он в три раза быстрее, чем Grid Search CV. Дадим ему значение «RS».
# - `feature_reduction`: Установим значение true, чтобы учитывать самую важную предикторную переменную для создания модели.
# - `scoring_parameter`: вы можете задать свой собственный параметр для скоринга, либо он будет выбран в соответствии с моделью. Здесь мы используем «Weighted-f1».
# - `KMeans_featurizer`: этот параметр должен стоять в значении true для линейного классификатора и false для XGboost или случайного классификатора, иначе есть риск переобучения.
# - `boosting_flag`: используется для бустинга. Поставим значение false.
# - `binning_flag`: по умолчанию стоит в значении false, но может быть установлен в true, когда мы хотим преобразовать верхние численные переменные в двоичные.
# - `add_poly`: установим в false.
# - `stacking_flag`: по умолчанию стоит в false. Если поставим значение true, то будет добавлена дополнительная функция, которая является производной от предсказаний другой модели. Оставим в значении false.
# - `Imbalanced_flag`: если стоит значение true, то проверит данные на сбалансированность и уберет дисбаланс методом SMOTING.
# - `Verbose`: обычно используется для вывода выполняемых шагов. Поставим значение 3.
#
# https://habr.com/ru/company/otus/blog/525292/

# %%
model, features, trainm, testm = Auto_ViML(
    train=data,
    target='risk',
    test='',
    sample_submission="",
    hyper_param="RS",
    feature_reduction=True,
    scoring_parameter="roc-auc",
    KMeans_Featurizer=False,
    Boosting_Flag=False,
    Binning_Flag=False,
    Add_Poly=False,
    Stacking_Flag=False,
    Imbalanced_Flag=False,
    verbose=3
)
# Out:
# ##############  D A T A   S E T  A N A L Y S I S  #######################
# ALERT! Changing hyperparameter search to RS. Otherwise, Random Forests will take too long for 10,000+ rows
# Training Set Shape = (735432, 30)
#     Training Set Memory Usage = 173.94 MB
# Single_Label Target: ['risk']
# Random shuffling the data set before training
#     Using RandomizedSearchCV for Hyper Parameter Tuning. This is 3X faster than GridSearchCV...
# ALERT! Setting Imbalanced_Flag to True in Auto_ViML for Multi_Classification problems improves results!
#        Class  -> Counts -> Percent
#          0.0:  394286  ->   53.6%
#          0.1:   65191  ->    8.9%
#          0.2:  118853  ->   16.2%
#          0.3:    1125  ->    0.2%
#          0.4:     198  ->    0.0%
#          0.5:   31264  ->    4.3%
#          0.7:    2270  ->    0.3%
#          0.8:     475  ->    0.1%
#          0.9:   21778  ->    3.0%
#         0.95:   59893  ->    8.1%
#          1.0:   40099  ->    5.5%
#     Target risk is already numeric. No transformation done.
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     29 Predictors classified...
#         This does not include the Target column(s)
#     7 variables removed since they were ID or low-information variables
#         ['F ТМ', 'I ТМ', 'W акт (ТМ) Вт', 'Дисб. U (ТМ) ', 'Э/э (Wакт)', 'Э/э реакт. (ТМ)', 'Э/э счет. (ТМ)']
# Number of Processors on this device = 1
# CPU available
#     No GPU active on this device
# #############     D A T A    P R E P A R A T I O N   AND C L E A N I N G     #############
# Filling missing values with "missing" placeholder and adding a column for missing_flags
#     Columns with most missing values: ['Э/э (Wакт)', 'Э/э реакт. (ТМ)', 'Э/э счет. (ТМ)', 'Дисб. U (ТМ) ', 'W акт (ТМ) Вт']
#     and their missing value totals: [734283, 734002, 732913, 709619, 699971]
# Completed missing value Imputation. No more missing values in train.
#     20 new missing value columns added: ['Cos ф (ТМ)_Missing_Flag', 'F вращ ТМ_Missing_Flag', 'I A ТМ_Missing_Flag', 'I C ТМ_Missing_Flag', 'I В ТМ_Missing_Flag', 'R изол ТМ_Missing_Flag', 'U AB (ТМ)_Missing_Flag', 'U BC (ТМ)_Missing_Flag', 'U CA (ТМ)_Missing_Flag', 'Дисб. I (ТМ) _Missing_Flag', 'Загр. ПЭД (ТМ)_Missing_Flag', 'Рэцн ТМ_Missing_Flag', 'Тдвиг ТМ_Missing_Flag', 'Темп. ж. ТМ_Missing_Flag', 'Рлин ТМ_Missing_Flag', 'Qгаз ТМ_Missing_Flag', 'Qж ТМ_Missing_Flag', 'Qж_мас ТМ_Missing_Flag', 'Qн ТМ_Missing_Flag', 'Обв ТМ_Missing_Flag']
#     Completed Label Encoding and Filling of Missing Values for Train and Test Data
# Multi_Classification problem: hyperparameters are being optimized for balanced_accuracy
# ############# R E M O V I N G   H I G H L Y  C O R R E L A T E D    V A R S #################
# Removing highly correlated variables using SULA method among (42) numeric variables
#
# Highly correlated columns to remove: ['F вращ ТМ', 'I A ТМ', 'I C ТМ', 'I В ТМ', 'U AB (ТМ)', 'U BC (ТМ)', 'U CA (ТМ)', 'Загр. ПЭД (ТМ)', 'Рэцн ТМ', 'Темп. ж. ТМ', 'Рлин ТМ', 'Qж_мас ТМ', 'Обв ТМ']
# Splitting features into float and categorical (integer) variables:
#     (7) float variables ...
#     (0) categorical vars...
# ############## F E A T U R E   S E L E C T I O N    BY   X G B O O S T    ####################
# Current number of predictors = 7
#     Finding Important Features using Boosted Trees algorithm...
#         using 7 variables...
#         using 5 variables...
#         using 3 variables...
#         using 1 variables...
# Found 7 important features
#     Performing limited feature engineering for binning, add_poly and KMeans_Featurizer flags  ...
#     Train CV Split completed with TRAIN rows =  588345 , CV rows =  147087
#     Binning_Flag set to False or there are no float vars in data set to be binned
#     KMeans_Featurizer set to False or there are no float variables in data
# Performing MinMax scaling of train and validation data
# ############### Forests M O D E L   B U I L D I N G  B E G I N S  ####################
# Rows in Train data set = 588345
#   Features in Train data set = 7
#     Rows in held-out data set = 147087
# Finding Best Model and Hyper Parameters for Forests model...
#     Baseline Accuracy Needed for Model = 94.55%
#     CPU Count = 8 in this device
# Using Forests Model, Estimated Training time = 226.51 mins
# Training regular model first time is Erroring: Check if your Input is correct...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-1a606d21c0aa> in <module>
# ----> 1 model, features, trainm, testm = Auto_ViML(
#       2     train=data,
#       3     target='risk',
#       4     test='',
#       5     sample_submission="",
#
# TypeError: cannot unpack non-iterable NoneType object
