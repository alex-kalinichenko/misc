# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
# %matplotlib inline

x = np.linspace(0, 1000, 1000)
plt.plot(x, np.log(x)/x)
plt.grid(True)
ylim(-1, 1)
xlim(0,100)
# Out:
# C:\Users\Alexx\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys
# (0.0, 100.0)

# %% [markdown]
# Исследование функции f(x) = x<sup>3</sup> + x<sup>2</sup>

# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
# %matplotlib inline

x = np.linspace(-10, 10, 1000)
y = x**3 - x**2
plt.plot(x, y)
plt.grid(True)
ylim(-1, 1)
xlim(-5,5)
# Out:
# (-5.0, 5.0)

# %% [markdown]
# Пример функции, не имеющей предела в нуле

# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
# %matplotlib inline

x = np.linspace(-10, 10, 1000)
y = sin(1/x)
plt.plot(x, y)
plt.grid(True)
ylim(-1, 1)
xlim(-2,2)
# Out:
# (-2.0, 2.0)

# %% [markdown]
# Пример функции, не имеющей предела в нуле и в бесконечностях

# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
# %matplotlib inline

x = np.linspace(-10, 10, 100)
y = np.sin(2*x)/3*x
plt.plot(x, y)
plt.grid(True)
# ylim(-1, 1)
# xlim(-2,2)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import scipy.linalg
from pylab import *
from mpl_toolkits.mplot3d import Axes3D

fig = figure()
ax = Axes3D(fig)
x = np.arange(-8, 8, 0.1)
y = np.arange(-8, 8, 0.1)
x, y = np.meshgrid(x, y)

ax.plot_surface(x, y, (1 - x**3)**(1/2) + np.log(y**2 - 1));
# Out:
# C:\Users\Alexx\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in sqrt
#
# C:\Users\Alexx\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in log
#
# C:\Users\Alexx\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: UserWarning: Z contains NaN values. This may result in rendering artifacts.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import scipy.linalg
from pylab import *
from mpl_toolkits.mplot3d import Axes3D

fig = figure()
ax = Axes3D(fig)
x = np.arange(-1, 1, 0.1)
y = np.arange(-1, 1, 0.1)
x, y = np.meshgrid(x, y)

ax.plot_surface(x, y, 2*x**2 + 2*x*y + 32*y**2 + 15);

# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
# %matplotlib inline

x = np.linspace(0, 1000, 1000)
plt.plot(x, x**(1/x))
plt.grid(True)
#ylim(-1, 1)
xlim(0,500)
# Out:
# C:\Users\Alexx\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in true_divide
#   import sys
# (0.0, 500.0)
