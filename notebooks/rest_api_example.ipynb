# %% [markdown]
# # Вывод списка репозиториев github для конкретного пользователя c сохранением JSON-вывода в файле *.json.

# %%
import requests
import json

main_link = 'https://api.github.com/users/'
user = 'kuvakina'
info = 'repos'
headers = {'User-Agent': 'Chrome/83.0.4103.61',
           'Accept': '*/*'}
try:
    response = requests.get(main_link + user + '/' + info, headers=headers, timeout=5)
    data = response.json()
    print(response.text)
    repos_list = []
    print('\n', 'Список ваших репозиториев:')
    for repo in data:
        print(repo['html_url'])
        repos_list.append(repo['html_url'])
    try:
        with open(f"github_repos_{user}.json.txt", "w", encoding="utf-8") as file_obj:
            for _ in repos_list:
                json.dump(_, file_obj)
                file_obj.write('\n')
    except IOError:
        print("Ошибка")

except requests.exceptions.ConnectTimeout:
    print('Connection timeout')
except requests.exceptions.ReadTimeout:
    print('Read timeout')
except requests.exceptions.HTTPError as e:
    print('Http error: %s' % e)
except requests.exceptions.ConnectionError:
    print('Connection error')
except requests.exceptions.RequestException:
    print('General Error')
# Out:
# [{"id":157736019,"node_id":"MDEwOlJlcG9zaXRvcnkxNTc3MzYwMTk=","name":"Helm-End2End-Tests","full_name":"kuvakina/Helm-End2End-Tests","private":false,"owner":{"login":"kuvakina","id":40596171,"node_id":"MDQ6VXNlcjQwNTk2MTcx","avatar_url":"https://avatars.githubusercontent.com/u/40596171?v=4","gravatar_id":"","url":"https://api.github.com/users/kuvakina","html_url":"https://github.com/kuvakina","followers_url":"https://api.github.com/users/kuvakina/followers","following_url":"https://api.github.com/users/kuvakina/following{/other_user}","gists_url":"https://api.github.com/users/kuvakina/gists{/gist_id}","starred_url":"https://api.github.com/users/kuvakina/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/kuvakina/subscriptions","organizations_url":"https://api.github.com/users/kuvakina/orgs","repos_url":"https://api.github.com/users/kuvakina/repos","events_url":"https://api.github.com/users/kuvakina/events{/privacy}","received_events_url":"https://api.github.com/users/kuvakina/received_events","type":"User","site_admin":false},"html_url":"https://github.com/kuvakina/Helm-End2End-Tests","description":null,"fork":true,"url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests","forks_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/forks","keys_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/keys{/key_id}","collaborators_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/teams","hooks_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/hooks","issue_events_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/issues/events{/number}","events_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/events","assignees_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/assignees{/user}","branches_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/branches{/branch}","tags_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/tags","blobs_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/git/refs{/sha}","trees_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/git/trees{/sha}","statuses_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/statuses/{sha}","languages_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/languages","stargazers_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/stargazers","contributors_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/contributors","subscribers_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/subscribers","subscription_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/subscription","commits_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/commits{/sha}","git_commits_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/git/commits{/sha}","comments_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/comments{/number}","issue_comment_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/issues/comments{/number}","contents_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/contents/{+path}","compare_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/compare/{base}...{head}","merges_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/merges","archive_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/downloads","issues_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/issues{/number}","pulls_url":"https://api.github.com/repos/kuvakina/Helm-End2End-Tests/pulls{/number}","milestones_url":"https://api.gith ...
#
#  Список ваших репозиториев:
# https://github.com/kuvakina/Helm-End2End-Tests
# https://github.com/kuvakina/Ripple-Stack-Vagrant-Docker

# %% [markdown]
# # Вывод вакансий по критериям из hh.ru

# %%
import requests
import json

main_link = 'https://api.hh.ru/'
method = 'vacancies'
text = 'text=python'
area = 'area=2'  # Saint-Petersburg
# справочник регионов: curl -k -H 'User-Agent':'api-test-agent' https://api.hh.ru/areas
metro = 'metro=15.217'  # Невский проспект
# справочник станций метро curl -k -H 'User-Agent':'api-test-agent' https://api.hh.ru/metro/2
# headers = {'User-Agent': 'Chrome/83.0.4103.61','Accept': '*/*'}
headers = {'User-Agent': 'api-test-agent', 'Accept': '*/*'}
try:
    response = requests.get(main_link + method + '?' + text + '&' + area + '&' + metro,
                            headers=headers, timeout=5)
    data = response.json()
    print(data)
    print(data['items'])
    # for position in data:
    #     print(position['name'])
        # repos_list.append(repo['html_url'])
    # try:
    #     with open(f"hh_{method}.json.txt", "w", encoding="utf-8") as file_obj:
    #         json.dump(data, file_obj)
    #         file_obj.write('\n')
    # except IOError:
    #     print("IO Error")

except requests.exceptions.ConnectTimeout:
    print('Connection timeout')
except requests.exceptions.ReadTimeout:
    print('Read timeout')
except requests.exceptions.HTTPError as e:
    print('Http error: %s' % e)
except requests.exceptions.ConnectionError:
    print('Connection error')
except requests.exceptions.RequestException:
    print('General Error')
# Out:
# {'items': [{'id': '44690811', 'premium': False, 'name': 'Data analyst в команду Видео', 'department': None, 'has_test': False, 'response_letter_required': False, 'area': {'id': '2', 'name': 'Санкт-Петербург', 'url': 'https://api.hh.ru/areas/2'}, 'salary': None, 'type': {'id': 'open', 'name': 'Открытая'}, 'address': {'city': 'Санкт-Петербург', 'street': '2 линия', 'building': 'метро Невский проспект', 'description': None, 'lat': 59.935574, 'lng': 30.327034, 'raw': 'Санкт-Петербург, 2 линия, метро Невский проспект', 'metro': {'station_name': 'Невский проспект', 'line_name': 'Московско-Петроградская', 'station_id': '15.217', 'line_id': '15', 'lat': 59.935421, 'lng': 30.327052}, 'metro_stations': [{'station_name': 'Невский проспект', 'line_name': 'Московско-Петроградская', 'station_id': '15.217', 'line_id': '15', 'lat': 59.935421, 'lng': 30.327052}], 'id': '1322501'}, 'response_url': None, 'sort_point_distance': None, 'published_at': '2021-05-18T20:33:48+0300', 'created_at': '2021-05-18T20:33:48+0300', 'archived': False, 'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=44690811', 'insider_interview': None, 'url': 'https://api.hh.ru/vacancies/44690811?host=hh.ru', 'alternate_url': 'https://hh.ru/vacancy/44690811', 'relations': [], 'employer': {'id': '63225', 'name': 'ВКонтакте', 'url': 'https://api.hh.ru/employers/63225', 'alternate_url': 'https://hh.ru/employer/63225', 'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/794119.png', '90': 'https://hhcdn.ru/employer-logo/3617363.png', '240': 'https://hhcdn.ru/employer-logo/3617364.png'}, 'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=63225', 'trusted': True}, 'snippet': {'requirement': 'Имеете опыт работы в продуктовой аналитике. Знаете математическую статистику и основы программирования. Умеете применять методы машинного обучения.', 'responsibility': 'Создавать и поддерживать регулярные аналитические расчёты. Работали с Apache Spark / ClickHouse.'}, 'contacts': None, 'schedule': {'id': 'remote', 'name': 'Удаленная работа'}, 'working_days': [], 'working_time_intervals': [], 'working_time_modes': [], 'accept_temporary': False}, {'id': '44007750', 'premium': False, 'name': 'Разработчик в команду прикладных исследований', 'department': None, 'has_test': False, 'response_letter_required': False, 'area': {'id': '2', 'name': 'Санкт-Петербург', 'url': 'https://api.hh.ru/areas/2'}, 'salary': None, 'type': {'id': 'open', 'name': 'Открытая'}, 'address': {'city': 'Санкт-Петербург', 'street': '2 линия', 'building': 'метро Невский проспект', 'description': None, 'lat': 59.935574, 'lng': 30.327034, 'raw': 'Санкт-Петербург, 2 линия, метро Невский проспект', 'metro': {'station_name': 'Невский проспект', 'line_name': 'Московско-Петроградская', 'station_id': '15.217', 'line_id': '15', 'lat': 59.935421, 'lng': 30.327052}, 'metro_stations': [{'station_name': 'Невский проспект', 'line_name': 'Московско-Петроградская', 'station_id': '15.217', 'line_id': '15', 'lat': 59.935421, 'lng': 30.327052}], 'id': '1322501'}, 'response_url': None, 'sort_point_distance': None, 'published_at': '2021-05-24T11:25:42+0300', 'created_at': '2021-05-24T11:25:42+0300', 'archived': False, 'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=44007750', 'insider_interview': None, 'url': 'https://api.hh.ru/vacancies/44007750?host=hh.ru', 'alternate_url': 'https://hh.ru/vacancy/44007750', 'relations': [], 'employer': {'id': '63225', 'name': 'ВКонтакте', 'url': 'https://api.hh.ru/employers/63225', 'alternate_url': 'https://hh.ru/employer/63225', 'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/794119.png', '90': 'https://hhcdn.ru/employer-logo/3617363.png', '240': 'https://hhcdn.ru/employer-logo/3617364.png'}, 'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=63225', 'trusted': True}, 'snippet': {'requirement': 'Понимаете концепции Deep Learning и можете свободно их применять. Знаете классические и современные подходы к обработке е ...
# [{'id': '44690811', 'premium': False, 'name': 'Data analyst в команду Видео', 'department': None, 'has_test': False, 'response_letter_required': False, 'area': {'id': '2', 'name': 'Санкт-Петербург', 'url': 'https://api.hh.ru/areas/2'}, 'salary': None, 'type': {'id': 'open', 'name': 'Открытая'}, 'address': {'city': 'Санкт-Петербург', 'street': '2 линия', 'building': 'метро Невский проспект', 'description': None, 'lat': 59.935574, 'lng': 30.327034, 'raw': 'Санкт-Петербург, 2 линия, метро Невский проспект', 'metro': {'station_name': 'Невский проспект', 'line_name': 'Московско-Петроградская', 'station_id': '15.217', 'line_id': '15', 'lat': 59.935421, 'lng': 30.327052}, 'metro_stations': [{'station_name': 'Невский проспект', 'line_name': 'Московско-Петроградская', 'station_id': '15.217', 'line_id': '15', 'lat': 59.935421, 'lng': 30.327052}], 'id': '1322501'}, 'response_url': None, 'sort_point_distance': None, 'published_at': '2021-05-18T20:33:48+0300', 'created_at': '2021-05-18T20:33:48+0300', 'archived': False, 'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=44690811', 'insider_interview': None, 'url': 'https://api.hh.ru/vacancies/44690811?host=hh.ru', 'alternate_url': 'https://hh.ru/vacancy/44690811', 'relations': [], 'employer': {'id': '63225', 'name': 'ВКонтакте', 'url': 'https://api.hh.ru/employers/63225', 'alternate_url': 'https://hh.ru/employer/63225', 'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/794119.png', '90': 'https://hhcdn.ru/employer-logo/3617363.png', '240': 'https://hhcdn.ru/employer-logo/3617364.png'}, 'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=63225', 'trusted': True}, 'snippet': {'requirement': 'Имеете опыт работы в продуктовой аналитике. Знаете математическую статистику и основы программирования. Умеете применять методы машинного обучения.', 'responsibility': 'Создавать и поддерживать регулярные аналитические расчёты. Работали с Apache Spark / ClickHouse.'}, 'contacts': None, 'schedule': {'id': 'remote', 'name': 'Удаленная работа'}, 'working_days': [], 'working_time_intervals': [], 'working_time_modes': [], 'accept_temporary': False}, {'id': '44007750', 'premium': False, 'name': 'Разработчик в команду прикладных исследований', 'department': None, 'has_test': False, 'response_letter_required': False, 'area': {'id': '2', 'name': 'Санкт-Петербург', 'url': 'https://api.hh.ru/areas/2'}, 'salary': None, 'type': {'id': 'open', 'name': 'Открытая'}, 'address': {'city': 'Санкт-Петербург', 'street': '2 линия', 'building': 'метро Невский проспект', 'description': None, 'lat': 59.935574, 'lng': 30.327034, 'raw': 'Санкт-Петербург, 2 линия, метро Невский проспект', 'metro': {'station_name': 'Невский проспект', 'line_name': 'Московско-Петроградская', 'station_id': '15.217', 'line_id': '15', 'lat': 59.935421, 'lng': 30.327052}, 'metro_stations': [{'station_name': 'Невский проспект', 'line_name': 'Московско-Петроградская', 'station_id': '15.217', 'line_id': '15', 'lat': 59.935421, 'lng': 30.327052}], 'id': '1322501'}, 'response_url': None, 'sort_point_distance': None, 'published_at': '2021-05-24T11:25:42+0300', 'created_at': '2021-05-24T11:25:42+0300', 'archived': False, 'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=44007750', 'insider_interview': None, 'url': 'https://api.hh.ru/vacancies/44007750?host=hh.ru', 'alternate_url': 'https://hh.ru/vacancy/44007750', 'relations': [], 'employer': {'id': '63225', 'name': 'ВКонтакте', 'url': 'https://api.hh.ru/employers/63225', 'alternate_url': 'https://hh.ru/employer/63225', 'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/794119.png', '90': 'https://hhcdn.ru/employer-logo/3617363.png', '240': 'https://hhcdn.ru/employer-logo/3617364.png'}, 'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=63225', 'trusted': True}, 'snippet': {'requirement': 'Понимаете концепции Deep Learning и можете свободно их применять. Знаете классические и современные подходы к обработке естественно ...
